# %% [markdown]
# # **Data Cleaning**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/raw_data_unmodified.csv', encoding = 'utf8')

# %%
df.movie_title.filter(regex = '2', axis = 0)
# Out:
# 2               Spectre?ÿ
# 12    Quantum of Solace?ÿ
# Name: movie_title, dtype: object

# %%
df[df.movie_title.str.match('Salma')]
# Out:
# Empty DataFrame
# Columns: [movie_title, num_critic_for_reviews, duration, DIRECTOR_facebook_likes, actor_3_facebook_likes, ACTOR_1_facebook_likes, gross, num_voted_users, Cast_Total_facebook_likes, facenumber_in_poster, num_user_for_reviews, budget, title_year, ACTOR_2_facebook_likes, imdb_score, title_year.1]
# Index: []

# %%
df.num_critic_for_reviews + df.duration
# Out:
# 0     901.0
# 1       NaN
# 2     750.0
# 3       NaN
# 4     594.0
# 5     548.0
# 6       NaN
# 7     776.0
# 8     776.0
# 9     528.0
# 10    856.0
# 11    603.0
# 12    509.0
# 13    464.0
# dtype: float64

# %%
df.movie_title + "***" + str(df.duration)
# Out:
# 0     Avatar?ÿ***0     178.0\n1       NaN\n2     148...
# 1     Pirates of the Caribbean: At World's End?ÿ***0...
# 2     Spectre?ÿ***0     178.0\n1       NaN\n2     14...
# 3     The Dark Knight Rises?ÿ***0     178.0\n1      ...
# 4     John Carter?ÿ***0     178.0\n1       NaN\n2   ...
# 5     Spider-Man 3?ÿ***0     178.0\n1       NaN\n2  ...
# 6     Tangled?ÿ***0     178.0\n1       NaN\n2     14...
# 7     Avengers: Age of Ultron?ÿ***0     178.0\n1    ...
# 8     Avengers: Age of Ultron?ÿ***0     178.0\n1    ...
# 9     Harry Potter and the Half-Blood Prince?ÿ***0  ...
# 10    Batman v Superman: Dawn of Justice?ÿ***0     1...
# 11    Superman Returns?ÿ***0     178.0\n1       NaN\...
# 12    Quantum of Solace?ÿ***0     178.0\n1       NaN...
# 13    Pirates of the Caribbean: Dead Man's Chest?ÿ**...
# Name: movie_title, dtype: object

# %%
df.movie_title.str.count(' ')
# Out:
# 0     0
# 1     6
# 2     0
# 3     3
# 4     1
# 5     1
# 6     0
# 7     3
# 8     3
# 9     5
# 10    5
# 11    1
# 12    2
# 13    6
# Name: movie_title, dtype: int64

# %%
df.movie_title.str.count(' ') + 2
# Out:
# 0     2
# 1     8
# 2     2
# 3     5
# 4     3
# 5     3
# 6     2
# 7     5
# 8     5
# 9     7
# 10    7
# 11    3
# 12    4
# 13    8
# Name: movie_title, dtype: int64

# %%
df.movie_title.str.split()
# Out:
# 0                                            [Avatar?ÿ]
# 1     [Pirates, of, the, Caribbean:, At, World's, En...
# 2                                           [Spectre?ÿ]
# 3                          [The, Dark, Knight, Rises?ÿ]
# 4                                      [John, Carter?ÿ]
# 5                                     [Spider-Man, 3?ÿ]
# 6                                           [Tangled?ÿ]
# 7                        [Avengers:, Age, of, Ultron?ÿ]
# 8                        [Avengers:, Age, of, Ultron?ÿ]
# 9       [Harry, Potter, and, the, Half-Blood, Prince?ÿ]
# 10          [Batman, v, Superman:, Dawn, of, Justice?ÿ]
# 11                                [Superman, Returns?ÿ]
# 12                              [Quantum, of, Solace?ÿ]
# 13    [Pirates, of, the, Caribbean:, Dead, Man's, Ch...
# Name: movie_title, dtype: object

# %%
df.movie_title.str.split().map(len)
# Out:
# 0     1
# 1     7
# 2     1
# 3     4
# 4     2
# 5     2
# 6     1
# 7     4
# 8     4
# 9     6
# 10    6
# 11    2
# 12    3
# 13    7
# Name: movie_title, dtype: int64

# %%
df.movie_title.str.split().apply(len).value_counts()
# Out:
# movie_title
# 1    3
# 4    3
# 2    3
# 7    2
# 6    2
# 3    1
# Name: count, dtype: int64

# %%
df.movie_title.str.split().str.len()
# Out:
# 0     1
# 1     7
# 2     1
# 3     4
# 4     2
# 5     2
# 6     1
# 7     4
# 8     4
# 9     6
# 10    6
# 11    2
# 12    3
# 13    7
# Name: movie_title, dtype: int64

# %%
df.rename(columns = {'movie_title' : 'uuuu'})
# Out:
#                                             uuuu  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.isna() # used to detect missing values
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        ACTOR_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %%
df['movie_title']
# Out:
# 0                                         Avatar?ÿ
# 1       Pirates of the Caribbean: At World's End?ÿ
# 2                                        Spectre?ÿ
# 3                          The Dark Knight Rises?ÿ
# 4                                    John Carter?ÿ
# 5                                   Spider-Man 3?ÿ
# 6                                        Tangled?ÿ
# 7                        Avengers: Age of Ultron?ÿ
# 8                        Avengers: Age of Ultron?ÿ
# 9         Harry Potter and the Half-Blood Prince?ÿ
# 10            Batman v Superman: Dawn of Justice?ÿ
# 11                              Superman Returns?ÿ
# 12                             Quantum of Solace?ÿ
# 13    Pirates of the Caribbean: Dead Man's Chest?ÿ
# Name: movie_title, dtype: object

# %%
x = ['salma', 'ali', 'NaN', 1899]

# %%
s = pd.Series(x)

# %%
s.str.split(" ")
# Out:
# 0    [salma]
# 1      [ali]
# 2      [NaN]
# 3        NaN
# dtype: object

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# # **How Reading Files**

# %%
df_tab = pd.read_table('/content/lyrics.txt')

# %%
df_tab.head(2)
# Out:
#                                   -Shape of you-
# 0  The club isn't the best place to find a lover
# 1                       So the bar is where I go

# %%
sd = pd.read_excel('/content/titanic.xlsx')

# %%
sd.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.0000      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
sd.tail(2)  #select last n rows
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1307       3         0  Zakarian, Mr. Ortin  male  27.0      0      0    2670
# 1308       3         0   Zimmerman, Mr. Leo  male  29.0      0      0  315082
#
#        fare cabin embarked boat  body home.dest
# 1307  7.225   NaN        C  NaN   NaN       NaN
# 1308  7.875   NaN        S  NaN   NaN       NaN

# %%
import zipfile as zp
archive = zp.ZipFile('/content/dataset.zip', 'r')

# %%
# List the contents of the ZIP file
print(archive.namelist())
# Out:
# ['dataset/dataset.csv', 'dataset/lyrics-Alanwalker(8).txt', 'dataset/raw_data_unmodified.csv']

# %%
with archive.open('dataset/raw_data_unmodified.csv') as file:
    df = pd.read_csv(file)

print(df.head())
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# another way
zzz = archive.read('dataset/raw_data_unmodified.csv')
zzz
# Out:
# b'movie_title,num_critic_for_reviews,duration,DIRECTOR_facebook_likes,actor_3_facebook_likes,ACTOR_1_facebook_likes,gross,num_voted_users,Cast_Total_facebook_likes,facenumber_in_poster,num_user_for_reviews,budget,title_year,ACTOR_2_facebook_likes,imdb_score,title_year\r\nAvatar?\xc3\xbf,723,178,10,855,1000,760505847,886204,4834,,3054,237000000,2009,936,7.9,2009\r\nPirates of the Caribbean: At World\'s End?\xc3\xbf,302,,563,1000,40000,309404152,471220,48350,,1238,300000000,2007,5000,7.1,\r\nSpectre?\xc3\xbf,602,148,20,161,11000,200074175,275868,11700,1,994,245000000,2015,393,6.8,2015\r\nThe Dark Knight Rises?\xc3\xbf,813,,22000,23000,27000,448130642,1144337,106759,,2701,250000000,2012,23000,8.5,\r\nJohn Carter?\xc3\xbf,462,132,"""475""",530,640,73058679,212204,1873,1,738,263700000,2012,632,6.6,\r\nSpider-Man 3?\xc3\xbf,392,156,23,4000,24000,336530303,383056,46055,,1902,258000000,2007,11000,6.2,2007\r\nTangled?\xc3\xbf,324,,15,284,799,200807262,294810,,1,387,260000000,2010,553,7.8,\r\n
# ...

# %%
with archive.open('dataset/lyrics-Alanwalker(8).txt') as file:
     text_content = file.read().decode('utf-8')

print(text_content)
# Out:
# -Faded-
# You were the shadow to my light
# Did you feel us?
# Another star
# You fade away
# Afraid our aim is out of sight
# Wanna see us
# Alight
#
# Where are you now?
# Where are you now?
# Where are you now?
# Was it all in my fantasy?
# Where are you now?
# Were you only imaginary?
#
# Where are you now?
# Atlantis
# Under the sea
# Under the sea
# Where are you now?
# Another dream
# The monster's running wild inside of me
# I'm faded
# I'm faded
# So lost, I'm faded
# I'm faded
# So lost, I'm faded
#
# These shallow waters never met what I needed
# I'm letting go a deeper dive
# Eternal silence of the sea, I'm breathing
# Alive
#
# Where are you now?
# Where are you now?
# Under the bright but faded lights
# You've set my heart on fire
# Where are you now?
# Where are you now?
#
# Where are you now?
# Atlantis
# Under the sea
# Under the sea
# Where are you now?
# Another dream
# The monster's running wild inside of me
# I'm faded
# I'm faded
# So lost, I'm faded
# ...
