# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/raw_data_unmodified.csv")

# %%
data.head(2)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
#
#    Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                     4834.0                   NaN                  3054
# 1                    48350.0                   NaN                  1238
#
#       budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0  237000000        2009                   936.0         7.9        2009.0
# ...

# %%
# Import Data To SQL
import sqlite3
#import sqlalchemy

# %%
# Connection To The DataBase
conn = sqlite3.connect("/content/raw_data_unmodified.sqlite3")

# %%
# Write DataFrame to SQL database
data.to_sql('data', conn, if_exists = 'replace', index = False) # Write the dataframe 'data' to a SQL table named 'data'
# Out:
# 14

# %%
# Read SQL Query Table into DataFrame
data_sql = pd.read_sql("SELECT * FROM data", conn)

# %%
data_sql.head(2)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
#
#    Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                     4834.0                   NaN                  3054
# 1                    48350.0                   NaN                  1238
#
#       budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0  237000000        2009                   936.0         7.9        2009.0
# ...

# %%
data_sql.tail(2)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
#     Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 12                     2023.0                   1.0                  1243
# 13                    48486.0                   2.0                  1832
#
#        budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 12  200000000        2008                   412.0         6.7        2008.0
# ...

# %%
conn.close() # Close the database connection

# %% [markdown]
# # **How To Preview Data in SQL**

# %%
# Activate SQL Magic
# %load_ext sql

# %%
# How To Load Database in SQL
# %sql sqlite:///raw_data_unmodified.sqlite3

# %%
# Method:1 "Line Oriented"
# %sql SELECT * FROM data;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ("Pirates of the Caribbean: At World's End?ÿ", 302, None, '563', 1000, 40000, 309404152, 471220.0, 48350.0, None, 1238, 300000000, 2007, 5000.0, 7.1, None),
#  ('Spectre?ÿ', 602, 148.0, '20', 161, 11000, 200074175, 275868.0, 11700.0, 1.0, 994, 245000000, 2015, 393.0, 6.8, 2015.0),
#  ('The Dark Knight Rises?ÿ', 813, None, '22000', 23000, 27000, 448130642, 1144337.0, 106759.0, None, 2701, 250000000, 2012, 23000.0, 8.5, None),
#  ('John Carter?ÿ', 462, 132.0, '"475"', 530, 640, 73058679, 212204.0, 1873.0, 1.0, 738, 263700000, 2012, 632.0, 6.6, None),
#  ('Spider-Man 3?ÿ', 392, 156.0, '23', 4000, 24000, 336530303, 383056.0, 46055.0, None, 1902, 258000000, 2007, 11000.0, 6.2, 2007.0),
#  ('Tangled?ÿ', 324, None, '15', 284, 799, 200807262, 294810.0, None, 1.0, 387, 260000000, 2010, 553.0, 7.8, None),
# ...

# %%
# Method:2 "Cell Oriented"
# %%sql
SELECT * FROM data
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ("Pirates of the Caribbean: At World's End?ÿ", 302, None, '563', 1000, 40000, 309404152, 471220.0, 48350.0, None, 1238, 300000000, 2007, 5000.0, 7.1, None),
#  ('Spectre?ÿ', 602, 148.0, '20', 161, 11000, 200074175, 275868.0, 11700.0, 1.0, 994, 245000000, 2015, 393.0, 6.8, 2015.0),
#  ('The Dark Knight Rises?ÿ', 813, None, '22000', 23000, 27000, 448130642, 1144337.0, 106759.0, None, 2701, 250000000, 2012, 23000.0, 8.5, None),
#  ('John Carter?ÿ', 462, 132.0, '"475"', 530, 640, 73058679, 212204.0, 1873.0, 1.0, 738, 263700000, 2012, 632.0, 6.6, None),
#  ('Spider-Man 3?ÿ', 392, 156.0, '23', 4000, 24000, 336530303, 383056.0, 46055.0, None, 1902, 258000000, 2007, 11000.0, 6.2, 2007.0),
#  ('Tangled?ÿ', 324, None, '15', 284, 799, 200807262, 294810.0, None, 1.0, 387, 260000000, 2010, 553.0, 7.8, None),
# ...

# %% [markdown]
# # **How To Get The First N-rows**

# %%
# %sql SELECT * FROM data LIMIT 2;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ("Pirates of the Caribbean: At World's End?ÿ", 302, None, '563', 1000, 40000, 309404152, 471220.0, 48350.0, None, 1238, 300000000, 2007, 5000.0, 7.1, None)]

# %%
# %%sql
# SELECT * FROM data LIMIT 2;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ("Pirates of the Caribbean: At World's End?ÿ", 302, None, '563', 1000, 40000, 309404152, 471220.0, 48350.0, None, 1238, 300000000, 2007, 5000.0, 7.1, None)]

# %% [markdown]
# # **# How To Get Table info/dtypes**

# %%
data.columns #Pandas
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
data.dtypes #Pandas
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
data.describe()  #Pandas
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        ACTOR_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %%
# %sql PRAGMA table_info(data);  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [(0, 'movie_title', 'TEXT', 0, None, 0),
#  (1, 'num_critic_for_reviews', 'INTEGER', 0, None, 0),
#  (2, 'duration', 'REAL', 0, None, 0),
#  (3, 'DIRECTOR_facebook_likes', 'TEXT', 0, None, 0),
#  (4, 'actor_3_facebook_likes', 'INTEGER', 0, None, 0),
#  (5, 'ACTOR_1_facebook_likes', 'INTEGER', 0, None, 0),
#  (6, 'gross', 'INTEGER', 0, None, 0),
#  (7, 'num_voted_users', 'REAL', 0, None, 0),
#  (8, 'Cast_Total_facebook_likes', 'REAL', 0, None, 0),
#  (9, 'facenumber_in_poster', 'REAL', 0, None, 0),
#  (10, 'num_user_for_reviews', 'INTEGER', 0, None, 0),
#  (11, 'budget', 'INTEGER', 0, None, 0),
#  (12, 'title_year', 'INTEGER', 0, None, 0),
#  (13, 'ACTOR_2_facebook_likes', 'REAL', 0, None, 0),
#  (14, 'imdb_score', 'REAL', 0, None, 0),
#  (15, 'title_year.1', 'REAL', 0, None, 0)]

# %% [markdown]
# # **How To Select Columns/Fields**

# %%
data.loc[:, ["movie_title"]]  #Pandas
# Out:
#                                      movie_title
# 0                                       Avatar?ÿ
# 1     Pirates of the Caribbean: At World's End?ÿ
# 2                                      Spectre?ÿ
# 3                        The Dark Knight Rises?ÿ
# 4                                  John Carter?ÿ
# 5                                 Spider-Man 3?ÿ
# 6                                      Tangled?ÿ
# 7                      Avengers: Age of Ultron?ÿ
# 8                      Avengers: Age of Ultron?ÿ
# 9       Harry Potter and the Half-Blood Prince?ÿ
# 10          Batman v Superman: Dawn of Justice?ÿ
# 11                            Superman Returns?ÿ
# 12                           Quantum of Solace?ÿ
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ

# %%
data.movie_title  #Pandas
# Out:
# 0                                         Avatar?ÿ
# 1       Pirates of the Caribbean: At World's End?ÿ
# 2                                        Spectre?ÿ
# 3                          The Dark Knight Rises?ÿ
# 4                                    John Carter?ÿ
# 5                                   Spider-Man 3?ÿ
# 6                                        Tangled?ÿ
# 7                        Avengers: Age of Ultron?ÿ
# 8                        Avengers: Age of Ultron?ÿ
# 9         Harry Potter and the Half-Blood Prince?ÿ
# 10            Batman v Superman: Dawn of Justice?ÿ
# 11                              Superman Returns?ÿ
# 12                             Quantum of Solace?ÿ
# 13    Pirates of the Caribbean: Dead Man's Chest?ÿ
# Name: movie_title, dtype: object

# %%
data["duration"] #Pandas
# Out:
# 0     178.0
# 1       NaN
# 2     148.0
# 3       NaN
# 4     132.0
# 5     156.0
# 6       NaN
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64

# %%
# %%sql
# SELECT movie_title FROM data;    #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ',),
#  ("Pirates of the Caribbean: At World's End?ÿ",),
#  ('Spectre?ÿ',),
#  ('The Dark Knight Rises?ÿ',),
#  ('John Carter?ÿ',),
#  ('Spider-Man 3?ÿ',),
#  ('Tangled?ÿ',),
#  ('Avengers: Age of Ultron?ÿ',),
#  ('Avengers: Age of Ultron?ÿ',),
#  ('Harry Potter and the Half-Blood Prince?ÿ',),
#  ('Batman v Superman: Dawn of Justice?ÿ',),
#  ('Superman Returns?ÿ',),
#  ('Quantum of Solace?ÿ',),
#  ("Pirates of the Caribbean: Dead Man's Chest?ÿ",)]

# %%
# select multiple cols/fields in Pandas
data[["movie_title", "duration"]]
# Out:
#                                      movie_title  duration
# 0                                       Avatar?ÿ     178.0
# 1     Pirates of the Caribbean: At World's End?ÿ       NaN
# 2                                      Spectre?ÿ     148.0
# 3                        The Dark Knight Rises?ÿ       NaN
# 4                                  John Carter?ÿ     132.0
# 5                                 Spider-Man 3?ÿ     156.0
# 6                                      Tangled?ÿ       NaN
# 7                      Avengers: Age of Ultron?ÿ     141.0
# 8                      Avengers: Age of Ultron?ÿ     141.0
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0
# 11                            Superman Returns?ÿ     169.0
# 12                           Quantum of Solace?ÿ     106.0
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0

# %%
# select multiple cols/fields in Pandas
data.loc[:, ["movie_title", "duration"]]
# Out:
#                                      movie_title  duration
# 0                                       Avatar?ÿ     178.0
# 1     Pirates of the Caribbean: At World's End?ÿ       NaN
# 2                                      Spectre?ÿ     148.0
# 3                        The Dark Knight Rises?ÿ       NaN
# 4                                  John Carter?ÿ     132.0
# 5                                 Spider-Man 3?ÿ     156.0
# 6                                      Tangled?ÿ       NaN
# 7                      Avengers: Age of Ultron?ÿ     141.0
# 8                      Avengers: Age of Ultron?ÿ     141.0
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0
# 11                            Superman Returns?ÿ     169.0
# 12                           Quantum of Solace?ÿ     106.0
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0

# %%
# How To Select Columns/Fields in SQL
# %%sql
SELECT movie_title, duartion FROM data;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# (sqlite3.OperationalError) no such column: duartion
# [SQL: SELECT movie_title, duartion FROM data;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# # **Condition Based Selection**

# %%
data[data["duration"] <= 150]   #Pandas
# Out:
#                   movie_title  num_critic_for_reviews  duration  \
# 2                   Spectre?ÿ                     602     148.0
# 4               John Carter?ÿ                     462     132.0
# 7   Avengers: Age of Ultron?ÿ                     635     141.0
# 8   Avengers: Age of Ultron?ÿ                     635     141.0
# 12        Quantum of Solace?ÿ                     403     106.0
#
#    DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 2                       20                     161                   11000
# 4                    "475"                     530                     640
# 7                       10                   19000                   26000
# 8                       10                   19000                   26000
# 12                     395                     393                     451
#
#         gross  num_voted_users  Cast_Total_facebook_likes  \
# 2   200074175         275868.0                    11700.0
# ...

# %%
data["duration"] <= 150   #Pandas
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# Name: duration, dtype: bool

# %%
# %%sql
# SELECT * FROM data WHERE duration <= 150;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Spectre?ÿ', 602, 148.0, '20', 161, 11000, 200074175, 275868.0, 11700.0, 1.0, 994, 245000000, 2015, 393.0, 6.8, 2015.0),
#  ('John Carter?ÿ', 462, 132.0, '"475"', 530, 640, 73058679, 212204.0, 1873.0, 1.0, 738, 263700000, 2012, 632.0, 6.6, None),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, None),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, 2015.0),
#  ('Quantum of Solace?ÿ', 403, 106.0, '395', 393, 451, 168368427, 330784.0, 2023.0, 1.0, 1243, 200000000, 2008, 412.0, 6.7, 2008.0)]

# %% [markdown]
# # **Filter All Values In Column That Begin|End With A**

# %%
data["movie_title"].str.startswith("A") #Pandas
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: movie_title, dtype: bool

# %%
data[data["movie_title"].str.startswith("A")] #Pandas
# Out:
#                  movie_title  num_critic_for_reviews  duration  \
# 0                   Avatar?ÿ                     723     178.0
# 7  Avengers: Age of Ultron?ÿ                     635     141.0
# 8  Avengers: Age of Ultron?ÿ                     635     141.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                      10                     855                    1000
# 7                      10                   19000                   26000
# 8                      10                   19000                   26000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 0  760505847         886204.0                     4834.0
# 7  458991599         462669.0                    92000.0
# 8  458991599         462669.0                    92000.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 0                   NaN                  3054  237000000        2009
# ...

# %%
data["movie_title"].str.endswith("A") #Pandas
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: movie_title, dtype: bool

# %%
data[data["movie_title"].str.endswith("A")] #Pandas
# Out:
# Empty DataFrame
# Columns: [movie_title, num_critic_for_reviews, duration, DIRECTOR_facebook_likes, actor_3_facebook_likes, ACTOR_1_facebook_likes, gross, num_voted_users, Cast_Total_facebook_likes, facenumber_in_poster, num_user_for_reviews, budget, title_year, ACTOR_2_facebook_likes, imdb_score, title_year.1]
# Index: []

# %%
# %%sql
# SELECT * FROM data WHERE movie_title LIKE 'A%';  #SQL Start With A And Follow It By Any No Of Chars
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, None),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, 2015.0)]

# %%
# %%sql
# SELECT * FROM data WHERE movie_title LIKE '%A';  #SQL End With A
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# []

# %% [markdown]
# # **Select Rows Which Contain Particular Term**

# %%
data[data["movie_title"].str.contains("Avatar")] #Pandas
# Out:
#   movie_title  num_critic_for_reviews  duration DIRECTOR_facebook_likes  \
# 0    Avatar?ÿ                     723     178.0                      10
#
#    actor_3_facebook_likes  ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                     855                    1000  760505847         886204.0
#
#    Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                     4834.0                   NaN                  3054
#
#       budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0  237000000        2009                   936.0         7.9        2009.0

# %%
# %%sql
# SELECT * FROM data WHERE movie_title LIKE '%Avatar%';  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0)]

# %% [markdown]
# # **Select Rows Which Contain Value**

# %%
data[data["movie_title"].isin(["Avatar"])] #Pandas
# Out:
# Empty DataFrame
# Columns: [movie_title, num_critic_for_reviews, duration, DIRECTOR_facebook_likes, actor_3_facebook_likes, ACTOR_1_facebook_likes, gross, num_voted_users, Cast_Total_facebook_likes, facenumber_in_poster, num_user_for_reviews, budget, title_year, ACTOR_2_facebook_likes, imdb_score, title_year.1]
# Index: []

# %%
# %%sql
# SELECT * FROM data WHERE movie_title IN ("Avatar");  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# []

# %% [markdown]
# # **Select Rows Which Meet Condition From 2-cols**

# %%
data[(data["duration"] == 178) & (data["movie_title"].str.startswith("A"))] #Pandas
# Out:
#   movie_title  num_critic_for_reviews  duration DIRECTOR_facebook_likes  \
# 0    Avatar?ÿ                     723     178.0                      10
#
#    actor_3_facebook_likes  ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                     855                    1000  760505847         886204.0
#
#    Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                     4834.0                   NaN                  3054
#
#       budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0  237000000        2009                   936.0         7.9        2009.0

# %%
# %%sql
# SELECT * FROM data WHERE duration = 178 AND movie_title LIKE 'A%';  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0)]

# %%
data[(data["duration"] == 178) | (data["movie_title"].str.startswith("A"))] #Pandas
# Out:
#                  movie_title  num_critic_for_reviews  duration  \
# 0                   Avatar?ÿ                     723     178.0
# 7  Avengers: Age of Ultron?ÿ                     635     141.0
# 8  Avengers: Age of Ultron?ÿ                     635     141.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                      10                     855                    1000
# 7                      10                   19000                   26000
# 8                      10                   19000                   26000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 0  760505847         886204.0                     4834.0
# 7  458991599         462669.0                    92000.0
# 8  458991599         462669.0                    92000.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 0                   NaN                  3054  237000000        2009
# ...

# %%
# %%sql
# SELECT * FROM data WHERE duration = 178 OR movie_title LIKE 'A%';  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 723, 178.0, '10', 855, 1000, 760505847, 886204.0, 4834.0, None, 3054, 237000000, 2009, 936.0, 7.9, 2009.0),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, None),
#  ('Avengers: Age of Ultron?ÿ', 635, 141.0, '10', 19000, 26000, 458991599, 462669.0, 92000.0, 4.0, 1117, 250000000, 2015, 21000.0, 7.5, 2015.0)]

# %% [markdown]
# # **Checking For Unique Values**

# %%
data["movie_title"].unique() #Pandas
# Out:
# array(['Avatar?ÿ', "Pirates of the Caribbean: At World's End?ÿ",
#        'Spectre?ÿ', 'The Dark Knight Rises?ÿ', 'John Carter?ÿ',
#        'Spider-Man 3?ÿ', 'Tangled?ÿ', 'Avengers: Age of Ultron?ÿ',
#        'Harry Potter and the Half-Blood Prince?ÿ',
#        'Batman v Superman: Dawn of Justice?ÿ', 'Superman Returns?ÿ',
#        'Quantum of Solace?ÿ',
#        "Pirates of the Caribbean: Dead Man's Chest?ÿ"], dtype=object)

# %%
# %%sql
# SELECT DISTINCT movie_title FROM data;  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ',),
#  ("Pirates of the Caribbean: At World's End?ÿ",),
#  ('Spectre?ÿ',),
#  ('The Dark Knight Rises?ÿ',),
#  ('John Carter?ÿ',),
#  ('Spider-Man 3?ÿ',),
#  ('Tangled?ÿ',),
#  ('Avengers: Age of Ultron?ÿ',),
#  ('Harry Potter and the Half-Blood Prince?ÿ',),
#  ('Batman v Superman: Dawn of Justice?ÿ',),
#  ('Superman Returns?ÿ',),
#  ('Quantum of Solace?ÿ',),
#  ("Pirates of the Caribbean: Dead Man's Chest?ÿ",)]

# %% [markdown]
# # **Number Of Unique Values**

# %%
data["movie_title"].nunique() #Pandas
# Out:
# 13

# %%
# %%sql
# SELECT COUNT(DISTINCT movie_title) FROM data;  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [(13,)]

# %% [markdown]
# # **Missing Values**

# %%
data.isna() #Pandas
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
data.isna().sum() #Pandas
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
data.isna().sum().sum() #Pandas
# Out:
# 21

# %%
data.isna().any() #Pandas
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
data.isna().any().any() #Pandas
# Out:
# True

# %%
data.isna().any().sum() #Pandas
# Out:
# 7

# %%
data.isna().sum().any() #Pandas
# Out:
# True

# %%
# %sql SELECT * FROM data WHERE Region IS NULL;  #SQL

# %%
# %sql SELECT * FROM data WHERE "duration" IS NULL;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [("Pirates of the Caribbean: At World's End?ÿ", 302, None, '563', 1000, 40000, 309404152, 471220.0, 48350.0, None, 1238, 300000000, 2007, 5000.0, 7.1, None),
#  ('The Dark Knight Rises?ÿ', 813, None, '22000', 23000, 27000, 448130642, 1144337.0, 106759.0, None, 2701, 250000000, 2012, 23000.0, 8.5, None),
#  ('Tangled?ÿ', 324, None, '15', 284, 799, 200807262, 294810.0, None, 1.0, 387, 260000000, 2010, 553.0, 7.8, None)]

# %%
# %%sql
# SELECT COUNT(*) - COUNT("movie_title") FROM data;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [(0,)]

# %% [markdown]
# # **Value Counts**

# %%
#Method_01 -> Pandas
data["movie_title"].value_counts()
# Out:
# movie_title
# Avengers: Age of Ultron?ÿ                       2
# Avatar?ÿ                                        1
# Pirates of the Caribbean: At World's End?ÿ      1
# Spectre?ÿ                                       1
# The Dark Knight Rises?ÿ                         1
# John Carter?ÿ                                   1
# Spider-Man 3?ÿ                                  1
# Tangled?ÿ                                       1
# Harry Potter and the Half-Blood Prince?ÿ        1
# Batman v Superman: Dawn of Justice?ÿ            1
# Superman Returns?ÿ                              1
# Quantum of Solace?ÿ                             1
# Pirates of the Caribbean: Dead Man's Chest?ÿ    1
# Name: count, dtype: int64

# %%
#Method_02 -> Pandas
data.groupby("movie_title").size()
# Out:
# movie_title
# Avatar?ÿ                                        1
# Avengers: Age of Ultron?ÿ                       2
# Batman v Superman: Dawn of Justice?ÿ            1
# Harry Potter and the Half-Blood Prince?ÿ        1
# John Carter?ÿ                                   1
# Pirates of the Caribbean: At World's End?ÿ      1
# Pirates of the Caribbean: Dead Man's Chest?ÿ    1
# Quantum of Solace?ÿ                             1
# Spectre?ÿ                                       1
# Spider-Man 3?ÿ                                  1
# Superman Returns?ÿ                              1
# Tangled?ÿ                                       1
# The Dark Knight Rises?ÿ                         1
# dtype: int64

# %%
# %%sql
# SELECT movie_title, COUNT(*) FROM data GROUP BY movie_title;  #SQL
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 1),
#  ('Avengers: Age of Ultron?ÿ', 2),
#  ('Batman v Superman: Dawn of Justice?ÿ', 1),
#  ('Harry Potter and the Half-Blood Prince?ÿ', 1),
#  ('John Carter?ÿ', 1),
#  ("Pirates of the Caribbean: At World's End?ÿ", 1),
#  ("Pirates of the Caribbean: Dead Man's Chest?ÿ", 1),
#  ('Quantum of Solace?ÿ', 1),
#  ('Spectre?ÿ', 1),
#  ('Spider-Man 3?ÿ', 1),
#  ('Superman Returns?ÿ', 1),
#  ('Tangled?ÿ', 1),
#  ('The Dark Knight Rises?ÿ', 1)]

# %%
# %%sql
# SELECT movie_title, COUNT(*) as my_count FROM data GROUP BY movie_title; # {replace COUNT(*) name with "my_count"}
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ', 1),
#  ('Avengers: Age of Ultron?ÿ', 2),
#  ('Batman v Superman: Dawn of Justice?ÿ', 1),
#  ('Harry Potter and the Half-Blood Prince?ÿ', 1),
#  ('John Carter?ÿ', 1),
#  ("Pirates of the Caribbean: At World's End?ÿ", 1),
#  ("Pirates of the Caribbean: Dead Man's Chest?ÿ", 1),
#  ('Quantum of Solace?ÿ', 1),
#  ('Spectre?ÿ', 1),
#  ('Spider-Man 3?ÿ', 1),
#  ('Superman Returns?ÿ', 1),
#  ('Tangled?ÿ', 1),
#  ('The Dark Knight Rises?ÿ', 1)]

# %% [markdown]
# # **Sum/Count/Avg/Mean/Max/....**

# %%
data["movie_title"].count() #Pandas
# Out:
# 14

# %%
data["movie_title"].sum() #Pandas
# Out:
# "Avatar?ÿPirates of the Caribbean: At World's End?ÿSpectre?ÿThe Dark Knight Rises?ÿJohn Carter?ÿSpider-Man 3?ÿTangled?ÿAvengers: Age of Ultron?ÿAvengers: Age of Ultron?ÿHarry Potter and the Half-Blood Prince?ÿBatman v Superman: Dawn of Justice?ÿSuperman Returns?ÿQuantum of Solace?ÿPirates of the Caribbean: Dead Man's Chest?ÿ"

# %%
data["movie_title"].min() #Pandas
# Out:
# 'Avatar?ÿ'

# %%
# %%sql
# SELECT MIN(movie_title) FROM data;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('Avatar?ÿ',)]

# %%
# %%sql
# SELECT MAX(movie_title) FROM data;
# Out:
#  * sqlite:///raw_data_unmodified.sqlite3
# Done.
# [('The Dark Knight Rises?ÿ',)]
